# %% [markdown]
# ## Setting up the environment

# %%
import sys
import os

# Add the parent directory to the system path
parent_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, parent_path)

import productivity_analytics

# Load the environment variables
from dotenv import load_dotenv # pip install python-dotenv

load_dotenv(parent_path + '/.env.dev')
repo_owner = os.getenv('repo_owner')
repo_name = os.getenv('repo_name')
token = os.getenv('token')

# %% [markdown]
# ## Background

# %% [markdown]
# There are two ways to collect data, the first being `get` and second being `update`. As per their names, `get` starts over from scratch and gets all data, and `update` updates that data. The process by which the data is initially built is as follows:
#
# 1) `get_pr_numbers` fetches all PR numbers based on `repo_owner` and `repo_name`. In the below examples `world-federation-of-advertisers/cross-media-measurement`.
# 2) Using the output of `get_pr_numbers` as the input for `build_pr_dataframe` yields a dataframe with data for each PR number. It's also possible to get raw JSON for individual PR number using `get_or_data`.
# 3) Similar to the above step, using the output of `get_pr_numbers` as the input for `build_review_dataframe` yields a dataframe with data for all the review comments for the given PR numbers.
#
# The above steps take roughly 2 second per PR. So 2,000 PRs will take about an hour to process. As the data is already available in `../data`, there is no need to go through these steps again, but one can simply update the datasets, where the process is as follows:
#
# 1) `get_pr_numbers` fetches all PR numbers based on `repo_owner` and `repo_name`.
# 2) Using the output of `get_pr_numbers` as the input for `update_pr_dataframe` yields an updated dataframe.
# 3) Similar to the above step, using the output of `get_pr_numbers` as the input for `update_review_dataframe` yields an updated dataframe

# %% [markdown]
# # 1. Build data from scratch i.e. `get`

# %% [markdown]
# ## 1.1. Get a list of PR numbers
# Fetches a list of all PR numbers for the repo

# %%
from productivity_analytics import get_pr_numbers

pr_numbers = get_pr_numbers(repo_owner, repo_name, token)

# %% [markdown]
# ## 1.2. Build PR data table
# Builds a PR dataframe based on all the PR numbers

# %%
from productivity_analytics import build_pr_dataframe

pr_df = build_pr_dataframe(pr_numbers[0:10], repo_owner, repo_name, token)

# %% [markdown]
# ## 1.2. Get PR data for each id
# Fetches the raw JSON data for a single PR number

# %%
from productivity_analytics import get_pr_data

pr_data = get_pr_data(pr_numbers[0], repo_owner, repo_name, token)

# %% [markdown]
# ## 1.3. Build Review data table
# Builds a review dataframe based on all the PR numbers

# %%
from productivity_analytics import build_review_dataframe

review_df = build_review_dataframe(pr_numbers,
                                   repo_owner,
                                   repo_name,
                                   token,
                                   save_to_file='../data/review_data.csv')

# %% [markdown]
# ## 1.3. Get review data for each PR number
# Fetches the raw JSON data for a single PR number

# %%
from productivity_analytics import get_review_data

review_data = get_review_data(pr_numbers[20], repo_owner, repo_name, token)

# %% [markdown]
# # 2. Update already built data i.e. `update`

# %% [markdown]
# ## 2.1. Get a list of PR numbers
# Fetches a list of all PR numbers for the repo

# %%
from productivity_analytics import get_pr_numbers

pr_numbers = get_pr_numbers(repo_owner, repo_name, token)

# %% [markdown]
# ## 2.2. Update PR data table
# Builds a PR dataframe based on existing and new PR numbers

# %%
from productivity_analytics import update_pr_data

pr_df = update_pr_data(repo_owner, repo_name, token)

# %% [markdown]
# ## 2.3. Update review data table
# Builds a review dataframe based on existing and new PR numbers

# %%
from productivity_analytics import update_review_data

update_review_data(repo_owner, repo_name, token, save_to_file=False)
# Out:
#               id  number                                           html_url  \
# 0     2253759183    1983  https://github.com/world-federation-of-adverti...
# 1     2247574277    1982  https://github.com/world-federation-of-adverti...
# 2     2246918549    1981  https://github.com/world-federation-of-adverti...
# 3     2245830434    1980  https://github.com/world-federation-of-adverti...
# 4     2245654089    1979  https://github.com/world-federation-of-adverti...
# ...          ...     ...                                                ...
# 1740   604965024       6  https://github.com/world-federation-of-adverti...
# 1741   604192038       5  https://github.com/world-federation-of-adverti...
# 1742   604043801       4  https://github.com/world-federation-of-adverti...
# 1743   603246119       2  https://github.com/world-federation-of-adverti...
# 1744   603183513       1  https://github.com/world-federation-of-adverti...
#
#        state  merged                                              title  \
# 0       open   False                 test: noise correction statistics.
# 1       open   False          feat!: Deploy Access as part of Reporting
# 2       open   False  style: Address lint errors in metric and metri...
# 3       open   False                   feat: implement Roles public api
# 4       open   False             build: Update common-jvm dep to 0.99.1
# ...      ...     ...                                                ...
# 1740  closed   False      Add EDP libraries for Requisition fulfillment
# 1741  closed    True    Implement skeletons of Panel Match public APIs.
# 1742  closed    True                 Add Panel Match tables to Kingdom.
# 1743  closed    True        Use non-experimental WFA workspace targets.
# 1744  closed    True      Add Cross-Media Measurement repo boilerplate.
#
#         user_login   user_id  \
# 0            ple13  15066084
# 1        SanjayVas   1747892
# 2      kungfucraig    700015
# 3     roaminggypsy  37773368
# 4        SanjayVas   1747892
# ...            ...       ...
# 1740   efoxepstein    127482
# 1741   efoxepstein    127482
# 1742   efoxepstein    127482
# 1743     SanjayVas   1747892
# 1744     SanjayVas   1747892
#
#                                                    body  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1740  This introduces a number of interfaces in ../d...
# 1741  This just adds the basic Kotlin classes and so...
# 1742  This is to support the centralized APIs for pa...
# 1743  This also uses the canonical reproducible form...
# 1744                                                NaN
#
#                      created_at                  closed_at  \
# 0     2024-12-27 21:27:17+00:00                        NaN
# 1     2024-12-21 02:09:44+00:00                        NaN
# 2     2024-12-20 15:37:22+00:00                        NaN
# 3     2024-12-20 02:02:10+00:00                        NaN
# 4     2024-12-19 22:48:46+00:00                        NaN
# ...                         ...                        ...
# 1740  2021-03-31 04:21:56+00:00  2021-08-24 16:53:42+00:00
# 1741  2021-03-30 18:09:53+00:00  2021-04-01 17:54:24+00:00
# 1742  2021-03-30 16:28:03+00:00  2021-04-07 16:13:03+00:00
# 1743  2021-03-29 23:59:42+00:00  2021-03-30 16:21:21+00:00
# 1744  2021-03-29 22:10:04+00:00  2021-03-29 22:45:07+00:00
#
#                       merged_at  comments  review_comments  \
# 0                           NaN         1                0
# 1                           NaN         1                0
# 2                           NaN         1                0
# 3                           NaN         1                0
# 4                           NaN         1                0
# ...                         ...       ...              ...
# 1740                        NaN         2                5
# 1741  2021-04-01 17:54:24+00:00         0                0
# 1742  2021-04-07 16:13:03+00:00         0                0
# 1743  2021-03-30 16:21:21+00:00         0                0
# 1744  2021-03-29 22:45:07+00:00         0                0
#
#                base_repo_name  commits  additions  deletions  changed_files
# 0     cross-media-measurement       24        896        102             12
# 1     cross-media-measurement        1        569        137             21
# 2     cross-media-measurement        4        103         43              3
# 3     cross-media-measurement        2        740          0              6
# 4     cross-media-measurement        1          6         45              3
# ...                       ...      ...        ...        ...            ...
# 1740  cross-media-measurement        1       1088          5             25
# 1741  cross-media-measurement        1        404          0              8
# 1742  cross-media-measurement        1         81          3              1
# 1743  cross-media-measurement        1         79         95              4
# 1744  cross-media-measurement        1        316          5              7
#
# [1745 rows x 19 columns]
