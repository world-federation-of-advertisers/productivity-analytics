# %%
import sys
sys.path.insert(0, '../productivity-analytics/')

import pandas as pd
import astetik

pr_df = pd.read_csv('pr_data.csv')
review_df = pd.read_csv('review_data.csv')

pr_df['type'] = 'pr'
review_df['type'] = 'review'

# %%
from productivity_analytics.plots import pr_open_to_resolve

pr_open_to_resolve(pr_df, review_df)

# %%
from productivity_analytics.plots import pr_per_contributor

pr_per_contributor(pr_df)
# Out:
#                    Percentage of All PRs
# user_login
# SanjayVas                          27.52
# tristanvuong2021                   13.70
# renjiezh                            9.98
# wangyaopw                           6.71
# riemanli                            4.53
# uakyol                              4.42
# efoxepstein                         3.21
# yunyeng                             2.64
# jcorilla                            2.64
# YuhongWang-Amazon                   2.35
# ple13                               2.24
# Marco-Premier                       2.12
# stevenwarejones                     2.06
# bdomen-ggl                          2.01
# iverson52000                        1.83
# chipingyeh                          1.55
# kungfucraig                         1.32
# jojijac0b                           1.26
# roaminggypsy                        1.15
# matthewclegg                        0.97
# jonmolle                            0.97
# robinsons                           0.92
# wfa-siyengar                        0.69
# oliver-amzn                         0.69
# wfa-mdharmalingam                   0.57
# duliomatos1                         0.52
# wfa-hkawalkar                       0.29
# enfreck                             0.29
# RibeiroAna                          0.17
# tcsnfkx                             0.17
# jgoodknight                         0.11
# mikkokotila                         0.11
# emadlivani                          0.06
# sandip80                            0.06
# xnegron                             0.06
# mallman                             0.06
# zasadnyy                            0.06

# %%
from productivity_analytics.plots import pr_comment_per_contributor

pr_comment_per_contributor(review_df)
# Out:
#                     Percentage of All Reviews
# user_login
# SanjayVas                               27.77
# stevenwarejones                         12.96
# tristanvuong2021                         7.94
# wangyaopw                                6.00
# kungfucraig                              4.92
# renjiezh                                 4.60
# riemanli                                 4.53
# efoxepstein                              4.52
# Marco-Premier                            3.92
# uakyol                                   3.23
# oliver-amzn                              2.03
# duliomatos1                              1.95
# ple13                                    1.88
# yunyeng                                  1.53
# iverson52000                             1.38
# chipingyeh                               1.10
# matthewclegg                             0.99
# YuhongWang-Amazon                        0.98
# jojijac0b                                0.91
# bdomen-ggl                               0.88
# wfa-siyengar                             0.88
# jcorilla                                 0.82
# robinsons                                0.82
# jiayu-google                             0.51
# zachcwc                                  0.51
# corbantek                                0.39
# roaminggypsy                             0.39
# jonmolle                                 0.35
# chenweiw                                 0.30
# wfa-hkawalkar                            0.27
# wfa-mdharmalingam                        0.18
# mariolamassaavedra                       0.12
# pasin30055                               0.07
# benjaminkreuter                          0.06
# RibeiroAna                               0.05
# emadlivani                               0.03
# jgoodknight                              0.03
# Jnf34                                    0.03
# sandip80                                 0.03
# mikkokotila                              0.03
# xnegron                                  0.02
# rmirisola                                0.02
# kgaynor                                  0.02
# enfreck                                  0.02
# cs-sswaminathan                          0.02
# wfa-reviewable                           0.01
# kunyuchen                                0.01
# TNATALI                                  0.01
# Theshadyasian                            0.01
# AlekseiS                                 0.01

# %%
from productivity_analytics.plots import pr_request_per_contributor

pr_request_per_contributor(review_df)
# Out:
#                    Percentage of All Change Requests
# user_login
# SanjayVas                                      52.99
# stevenwarejones                                15.25
# kungfucraig                                     5.82
# efoxepstein                                     5.40
# wangyaopw                                       5.10
# tristanvuong2021                                4.45
# riemanli                                        2.21
# renjiezh                                        1.41
# robinsons                                       1.33
# uakyol                                          1.18
# matthewclegg                                    1.07
# ple13                                           1.03
# Marco-Premier                                   0.65
# duliomatos1                                     0.46
# jiayu-google                                    0.30
# oliver-amzn                                     0.27
# iverson52000                                    0.27
# wfa-siyengar                                    0.11
# chipingyeh                                      0.11
# corbantek                                       0.11
# chenweiw                                        0.11
# jcorilla                                        0.08
# YuhongWang-Amazon                               0.08
# jonmolle                                        0.08
# jojijac0b                                       0.04
# RibeiroAna                                      0.04
# pasin30055                                      0.04
# rmirisola                                       0.04

# %%
from productivity_analytics.plots import pr_iterations_per_author

pr_iterations_per_author(pr_df, review_df)
# Out:
#                        count
# user_login
# duliomatos1        10.777778
# oliver-amzn         5.750000
# riemanli            4.630137
# jojijac0b           4.428571
# Marco-Premier       4.371429
# uakyol              3.984615
# iverson52000        3.967742
# ple13               3.729730
# chipingyeh          3.269231
# wfa-hkawalkar       2.800000
# yunyeng             2.711111
# kungfucraig         2.700000
# matthewclegg        2.625000
# wfa-siyengar        2.500000
# tristanvuong2021    2.377682
# roaminggypsy        2.235294
# renjiezh            2.139394
# bdomen-ggl          2.137931
# wangyaopw           1.974359
# YuhongWang-Amazon   1.944444
# jcorilla            1.866667
# efoxepstein         1.672727
# robinsons           1.533333
# jgoodknight         1.500000
# SanjayVas           1.224576
# stevenwarejones     1.200000
# jonmolle            1.000000
# wfa-mdharmalingam   0.700000
# RibeiroAna          0.333333
# enfreck             0.200000
# tcsnfkx             0.000000
# emadlivani          0.000000
# mallman             0.000000
# zasadnyy            0.000000
