# %%
import sys
import os

import astetik
import pandas as pd

# Add the parent directory to the system path
parent_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, parent_path)

import productivity_analytics

# Load the data from file
pr_df = pd.read_csv(parent_path + '/data/pr_data.csv')
review_df = pd.read_csv(parent_path + '/data/review_data.csv')

# Add a new column for type of data
pr_df['type'] = 'pr'
review_df['type'] = 'review'

# %% [markdown]
# ## Merged PR per Tag

# %% [markdown]
# Comparing the number of Conventional Commits tags in the PR title, gives an indication of how much resources go to different kinds of tasks, and can be summarized as "Sustaining Work vs. Transformative Work".
#
# **NOTE:** Data is here limited to starting from 1st of August, 2024. This is the time since we started to actively use the tags from Convetional Commits in our PR titles.

# %%
from productivity_analytics import merged_per_tag

merged_per_tag_data = merged_per_tag(pr_df)

# %%
from productivity_analytics import pr_per_tag

pr_per_tag(merged_per_tag_data)
# Out:
#           count  relative_share
# tag
# feat         49           34.75
# fix          40           28.37
# refactor     16           11.35
# build        12            8.51
# ci            8            5.67
# test          7            4.96
# docs          5            3.55
# style         2            1.42
# perf          1            0.71
# chore         1            0.71

# %%
from productivity_analytics import sustaining_vs_transformative

sustaining_vs_transformative(merged_per_tag_data)
# Out:
#                 count  relative_share
# type_of_work
# sustaining         75           53.19
# transformative     66           46.81

# %% [markdown]
# ## Merged vs. Not Merged

# %% [markdown]
# Comparing the number of merged vs. non-merged PRs per contributor, is a complimentary indicator for productivity issues at a contributor level, and can be summarized as `merge_rate` with higher values (max 100) indicating how degree of performed work ending up in production.

# %%
from productivity_analytics import merged_vs_not

merged_vs_not(pr_df)
# Out:
#                    merged_count  not_merged_count  total_prs  merge_rate
# user_login
# wangyaopw                   113                 4        117       96.58
# SanjayVas                   452                28        480       94.17
# robinsons                    15                 1         16       93.75
# yunyeng                      43                 3         46       93.48
# oliver-amzn                  11                 1         12       91.67
# efoxepstein                  51                 5         56       91.07
# duliomatos1                   8                 1          9       88.89
# tristanvuong2021            210                29        239       87.87
# riemanli                     69                10         79       87.34
# jojijac0b                    19                 3         22       86.36
# chipingyeh                   23                 4         27       85.19
# ple13                        34                 6         40       85.00
# iverson52000                 27                 5         32       84.38
# Marco-Premier                31                 6         37       83.78
# wfa-hkawalkar                 4                 1          5       80.00
# jcorilla                     36                10         46       78.26
# kungfucraig                  18                 5         23       78.26
# uakyol                       59                18         77       76.62
# renjiezh                    132                42        174       75.86
# YuhongWang-Amazon            29                12         41       70.73
# matthewclegg                 12                 5         17       70.59
# stevenwarejones              25                11         36       69.44
# bdomen-ggl                   23                12         35       65.71
# roaminggypsy                 13                 7         20       65.00
# jonmolle                      9                 8         17       52.94
# wfa-siyengar                  4                 8         12       33.33
# RibeiroAna                    1                 2          3       33.33
# wfa-mdharmalingam             3                 7         10       30.00

# %% [markdown]
# ## Wasted Reviews

# %% [markdown]
# Looking at the number of reviews an author receives for his/hers PRs that never get merged and contrasting it with the total number of PRs by the author is another way to identify loss of productivity.

# %%
from productivity_analytics import wasted_reviews

wasted_reviews(pr_df, review_df)
# Out:
#            user_login  review_comment_count  pr_count  review_waste_ratio
# 10          jojijac0b                     1        20                0.05
# 2           SanjayVas                    25       457                0.05
# 25          wangyaopw                    10       115                0.09
# 8        iverson52000                     3        29                0.10
# 6         duliomatos1                     1         9                0.11
# 18           riemanli                     9        73                0.12
# 20          robinsons                     3        16                0.19
# 26      wfa-hkawalkar                     1         5                0.20
# 30            yunyeng                     9        46                0.20
# 24             uakyol                    14        63                0.22
# 23   tristanvuong2021                    58       227                0.26
# 7         efoxepstein                    15        53                0.28
# 5          chipingyeh                     9        24                0.38
# 3   YuhongWang-Amazon                    14        34                0.41
# 16              ple13                    21        37                0.57
# 22    stevenwarejones                    17        29                0.59
# 17           renjiezh                    96       147                0.65
# 13       matthewclegg                    11        15                0.73
# 4          bdomen-ggl                    22        30                0.73
# 9            jcorilla                    36        44                0.82
# 15        oliver-amzn                    13        12                1.08
# 19       roaminggypsy                    22        18                1.22
# 0       Marco-Premier                    49        37                1.32
# 12        kungfucraig                    39        21                1.86
# 1          RibeiroAna                     6         3                2.00
# 11           jonmolle                    38        16                2.38
# 14        mikkokotila                     8         2                4.00
# 29            xnegron                     7         1                7.00
# 28       wfa-siyengar                    44         6                7.33
# 21           sandip80                     8         1                8.00
# 27  wfa-mdharmalingam                    80         8               10.00

# %% [markdown]
# ## Lines Added vs. Deleted

# %% [markdown]
# While not always straightforward to interpret, it can be sometimes useful to understand how authors are adding lines versus deleting lines in their PRs.

# %%
from productivity_analytics import lines_added_vs_deleted

lines_added_vs_deleted(pr_df)
# Out:
#                    total_prs  total_lines_added  total_lines_deleted  \
# user_login
# wangyaopw                117             203440                36184
# tristanvuong2021         239             115981                31014
# uakyol                    77              88365                 6866
# riemanli                  79              51503                 9299
# renjiezh                 174              53098                15212
# ple13                     40              42819                 5793
# SanjayVas                480             293102               258623
# Marco-Premier             37              41766                11126
# YuhongWang-Amazon         41              38278                 8100
# bdomen-ggl                35              25055                 2589
# yunyeng                   46              14801                 4985
# jojijac0b                 22              10237                  524
# jcorilla                  46              10866                 1325
# robinsons                 16               8045                 1183
# iverson52000              32               9259                 4287
# efoxepstein               56               9214                 4405
# chipingyeh                27               6580                 2120
# matthewclegg              17               4379                  200
# kungfucraig               23               4473                  512
# roaminggypsy              20               4109                  198
# sandip80                   1               5296                 2189
# wfa-mdharmalingam         10               3426                  430
# wfa-siyengar              12               2540                  603
# duliomatos1                9               2266                  373
# oliver-amzn               12               1128                  190
# wfa-hkawalkar              5                910                    7
# jonmolle                  17               1541                  885
# xnegron                    1                215                   13
# RibeiroAna                 3                107                   11
# jgoodknight                2                105                   10
# tcsnfkx                    3                 56                    4
# mikkokotila                2                 59                   30
# zasadnyy                   1                  1                    0
# mallman                    1                  1                    1
# emadlivani                 1                  1                    1
# enfreck                    5                261                  825
# stevenwarejones           36               7139               182161
#
#                    total_delta
# user_login
# wangyaopw               167256
# tristanvuong2021         84967
# uakyol                   81499
# riemanli                 42204
# renjiezh                 37886
# ple13                    37026
# SanjayVas                34479
# Marco-Premier            30640
# YuhongWang-Amazon        30178
# bdomen-ggl               22466
# yunyeng                   9816
# jojijac0b                 9713
# jcorilla                  9541
# robinsons                 6862
# iverson52000              4972
# efoxepstein               4809
# chipingyeh                4460
# matthewclegg              4179
# kungfucraig               3961
# roaminggypsy              3911
# sandip80                  3107
# wfa-mdharmalingam         2996
# wfa-siyengar              1937
# duliomatos1               1893
# oliver-amzn                938
# wfa-hkawalkar              903
# jonmolle                   656
# xnegron                    202
# RibeiroAna                  96
# jgoodknight                 95
# tcsnfkx                     52
# mikkokotila                 29
# zasadnyy                     1
# mallman                      0
# emadlivani                   0
# enfreck                   -564
# stevenwarejones        -175022
